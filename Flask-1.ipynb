# %%
"""QTS.1
Flask is a micro web framework written in Python. It is classified as a microframework
because it does not require particular tools or libraries. It has no database abstraction layer, 
form validation, or any other components where pre-existing third-party libraries provide 
common functions.

benefits:-
1.It is a lightweight framework that offers hassle-free development.
2.Provide flexibility to the developer to experiment with their modules or architecture.
3.It is suitable for small projects.
4.Offers a built-in development server and fast debugger.
5.Easily scalable for the applications.
6.Support for secure cookies"""
# Out:
# 'QTS.1\nFlask is a micro web framework written in Python. It is classified as a microframework\nbecause it does not require particular tools or libraries. It has no database abstraction layer, \nform validation, or any other components where pre-existing third-party libraries provide \ncommon functions.\n\nbenefits:-\n1.It is a lightweight framework that offers hassle-free development.\n2.Provide flexibility to the developer to experiment with their modules or architecture.\n3.It is suitable for small projects.\n4.Offers a built-in development server and fast debugger.\n5.Easily scalable for the applications.\n6.Support for secure cookies'

# %% [markdown]
# #qts. 2.
# #screenshot of the image and the code of the flask application saying hello
# #1.code sreenshot:-
# ![Screenshot (150).png](attachment:3fe29370-b836-4fd4-a64d-911f8e67337a.png)
# #2.screenshot of the runnng flask app url
# ![Screenshot (149).png](attachment:4f0d5ffb-0094-4af6-9a5d-c0457b88c7bf.png)

# %%
"""QTS.3
App Routing means mapping the URLs to a specific function that will handle the logic for that URL.

It is used to access some particular page like Flask Tutorial in the web application."""
# Out:
# 'QTS.3\nApp Routing means mapping the URLs to a specific function that will handle the logic for that URL.\n\nIt is used to access some particular page like Flask Tutorial in the web application.'

# %% [markdown]
# """QTS.4"""
# """screenshot of the code and the running flask code"""
# ![Screenshot (152).png](attachment:c9f73bbe-0223-4ce3-b9ac-72d59a8218c7.png)
# ![Screenshot (154).png](attachment:aba0e8a8-d0d6-4fb1-bedb-65e80532d789.png)
# ![Screenshot (153).png](attachment:a4b98b64-f3d9-44c8-94e0-fa248e6a19e8.png)

# %%
"""QTS.5
The url_for() function is used to build a URL to the specific function dynamically."""

from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'Welcome to the homepage!'

@app.route('/about')
def about():
    return 'This is the about page.'

@app.route('/contact')
def contact():
    return 'You can contact us here.'

if __name__ == '__main__':
    with app.test_request_context():
        print(url_for('index'))   # Output: '/'
        print(url_for('about'))   # Output: '/about'
        print(url_for('contact')) # Output: '/contact'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 """QTS.5
#       2 The url_for() function is used to build a URL to the specific function dynamically."""
# ----> 4 from flask import Flask, url_for
#       6 app = Flask(__name__)
#       8 @app.route('/')
#       9 def index():
#
# ModuleNotFoundError: No module named 'flask'
